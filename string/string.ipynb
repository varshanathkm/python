# %% [markdown]
# #string

# %% [markdown]
# string is a immutable datatype
#
# > allow duplicate elements
#
# > it is iterable
#
# > created by using single or double quotations

# %%
data = "hello raju how are you"

print(data)

print(type(data))
# Out:
# hello raju how are you
# <class 'str'>

# %% [markdown]
# #string indexing and slicing

# %%
data = "hello raju how are you"

print(data[0:5])
print(data[0:10])
print(data[0:19])
print(data[0:22])

print(type(data))
# Out:
# hello
# hello raju
# hello raju how are
# hello raju how are you
# <class 'str'>

# %% [markdown]
# #indexing

# %%
data = "hello raju how are you"

print(data[0])
print(data[1])
print(data[2])
print(data[3])
print(data[4])
print(data[-3])
print(data[-2])
print(data[-1])
print(type(data))
# Out:
# h
# e
# l
# l
# o
# y
# o
# u
# <class 'str'>

# %% [markdown]
# #string methods

# %% [markdown]
# ##capitalize method

# %%
data = "hello raju how are you"

data1 = data.capitalize()

print(data1)

print(type(data))
# Out:
# Hello raju how are you
# <class 'str'>

# %% [markdown]
# #casefold method

# %%
data = "HELLO raju how are you"

data1 = data.casefold()

print(data1)

print(type(data))
# Out:
# hello raju how are you
# <class 'str'>

# %% [markdown]
# #lower method

# %%
data = "HELLO RAJU HOW ARE YOU"

data1 = data.lower()

print(data1)

print(type(data))
# Out:
# hello raju how are you
# <class 'str'>

# %% [markdown]
# #upper method

# %%
data = "hello raju how are you"

data1 = data.upper()

print(data1)

print(type(data))
# Out:
# HELLO RAJU HOW ARE YOU
# <class 'str'>

# %% [markdown]
# #title method

# %% [markdown]
# used to capitalize first letter of every word in the sentence

# %%
data = "hello raju how are you"

data1 = data.title()

print(data1)

print(type(data))
# Out:
# Hello Raju How Are You
# <class 'str'>

# %% [markdown]
# #center method

# %% [markdown]
# the centre method is used to center a string within a specified width by padding it with a specified character(default is white space on both sides)

# %%
data = "raju"

data1 = data.center(20,'%')

print(data1)

print(len(data1))
# Out:
# %%%%%%%%raju%%%%%%%%
# 20

# %% [markdown]
# #count method

# %% [markdown]
# it is used to count number of occurence in a specific element or in a specific location

# %%
data = "hello raju how are you raju"

data1 = data.count('h')

print(data1)
# Out:
# 2

# %%
data = "hello raju how are you raju"

data1 = data.count('raju',3,15)

print(data1)
# Out:
# 1

# %% [markdown]
# #startswith and endswith

# %%
data = "hello raju how are you raju"

data1 = data.startswith('hello')

print(data1)
# Out:
# True

# %%
data = "hello raju how are you raju"

data1 = data.startswith('o r',4,8)

print(data1)
# Out:
# True

# %%
data = "hello raju how are you raju"

data1 = data.startswith('raju',6,11)

print(data1)
# Out:
# True

# %%
data = "hello raju how are you raju"

data1 = data.endswith('raju')

print(data1)
# Out:
# True

# %%
data = "hello raju how are you raju"

data1 = data.endswith('raju',6,10)

print(data1)
# Out:
# True

# %% [markdown]
# #isalpha

# %% [markdown]
# is used to check if the given data is alphabet

# %%
data = "hellorajuhowareyouraju"

data1 = data.isalpha()

print(data1)
# Out:
# True

# %% [markdown]
# > valid identifier needs to start with underscore or alphabets

# %% [markdown]
# #isascii

# %% [markdown]
# used to check if it contains any ascii characters

# %%
data = "hello 88raju how are you## raju"

data1 = data.isascii()

print(data1)
# Out:
# True

# %% [markdown]
# #isalnum

# %% [markdown]
# to check whether the string contains alphanumeric characters or elements

# %%
data = "hello raju8384y83499 how are you raju"

data1 = data.isalnum()

print(data1)
# Out:
# False

# %% [markdown]
# #endswith

# %%
data = "hello raju8384y83499 how are you raju"

data1 = data.endswith('raju',6,10)

print(data1)
# Out:
# True

# %% [markdown]
# #isdigit

# %% [markdown]
# it is used to check the string contains digits or numerical data

# %%
data = "888"

data1 = data.isdigit()

print(data1)
# Out:
# True

# %% [markdown]
# #islower

# %% [markdown]
# to check whether the given data is in lowercase

# %%
data = "hello raju how are you raju"

data1 = data.islower()

print(data1)
# Out:
# True

# %% [markdown]
# #isdecimal

# %% [markdown]
# used to check whether the given string has decimal values in it

# %%
data = "656565"

data1 = data.isdecimal()

print(data1)
# Out:
# True

# %% [markdown]
# #isidentifier

# %% [markdown]
# used to check if the string has identifiers in it

# %%
data = "877"

data1 = data.isdigit()

print(data1)
# Out:
# True

# %% [markdown]
# #isnumeric

# %% [markdown]
# to check if the string has only numeric values

# %%
data = "888"

data1 = data.isdigit()

print(data1)
# Out:
# True

# %% [markdown]
# #isprintable

# %% [markdown]
# to check if the string data is printable

# %%
data = "7874"

data1 = data.isprintable()

print(data1)
# Out:
# True

# %% [markdown]
# #isspace

# %% [markdown]
# used to check if the string contains only space

# %%
data = "   "

data1 = data.isspace()

print(data1)
# Out:
# True

# %% [markdown]
# #istitile

# %% [markdown]
# to check whether the first letter is uppercase or not

# %%
data = "Kevin"

data1 = data.istitle()

print(data1)
# Out:
# True

# %% [markdown]
# #isupper

# %% [markdown]
# to check whether the letters inside the string is capital only

# %%
data = "KEVIN"

data1 = data.isupper()

print(data1)
# Out:
# True

# %% [markdown]
# #find method

# %% [markdown]
# it is used get the first occurence or index postion of a particular letter

# %%
data = "hello raju how are you raju"

data1 = data.find('raju')

print(data1)
# Out:
# 6

# %% [markdown]
# #rfind method

# %% [markdown]
# used to find the last occurence of a specific letter

# %%
data = "hello raju how are you raju"

data1 = data.rfind('raju')

print(data1)
# Out:
# 23

# %% [markdown]
# #format method

# %% [markdown]
# it is used to input data that is given as a format

# %%
data = "my name is {} i am {} years old"

name = input('enter your name')
age = input('enter your age')

data1 = data.format(name,age)

print(data1)
# Out:
# enter your nameaju
# enter your age55
# my name is aju i am 55 years old

# %% [markdown]
# #replace method

# %% [markdown]
# it is used to raplce on data in a string with *another*

# %%
text = "hello raju how are you"

text1 = text.replace('raju','ramu')

print(text1)
# Out:
# hello ramu how are you

# %%
text = "raju hello raju how raju are you raju raju"

text1 = text.replace('raju','ramu',2)

print(text1)
# Out:
# ramu hello ramu how raju are you raju raju

# %% [markdown]
# this method helps replace raju 2 times

# %% [markdown]
# #split method

# %% [markdown]
# used to split the string data with particular condition like with a particular word or space

# %%
text = "raju hello raju how raju are you raju raju"

text1 = text.split(' ')

print(text1)
# Out:
# ['raju', 'hello', 'raju', 'how', 'raju', 'are', 'you', 'raju', 'raju']

# %%
text = "raju hello raju how raju are you raju raju"

text1 = text.split('y')

print(text1)
# Out:
# ['raju hello raju how raju are ', 'ou raju raju']

# %%
text = "raju hello raju how raju are you raju raju"

text1 = text.split('r')

print(text1)
# Out:
# ['', 'aju hello ', 'aju how ', 'aju a', 'e you ', 'aju ', 'aju']

# %% [markdown]
# #join method

# %% [markdown]
# used to combine a list of string data. to join a list data into a string

# %%
text = ['raju', 'hello', 'raju', 'how', 'raju', 'are', 'you', 'raju', 'raju']

text1 = " ".join(text)

print(text1)
# Out:
# raju hello raju how raju are you raju raju

# %%
text = ['raju', 'hello', 'raju', 'how', 'raju', 'are', 'you', 'raju', 'raju']

data = " "

text1 = data.join(text)

print(text1)
# Out:
# raju hello raju how raju are you raju raju
