# %% [markdown]
# ![Screenshot 2024-10-13 at 4.49.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# 1.valid identifier checking

# %%
data = input("enter a string: ")

#if data.isidentifier():
#if data[0].isalpha() or data[0] == '_' and data.replace('_', '').isalnum():
if('a'<=data[0]<='z' or 'A'<=data[0]<='Z' or data[0] == '_'):
  if('a'<=data[1]<='z' or 'A'<=data[1]<='Z' or data[1] == '_' or '0'<=data[1]<='9'):

    print("valid identifier")

else:

    print("invalid identifier")
# Out:
# enter a string: jgfd
# valid identifier

# %% [markdown]
# 1. valid identifier checking
#
# conditions:
# 1. the identifiers are seperated by spaces

# %%
data = input("enter a string")

data1 = data.split(' ')

#print(data1)
for i in data1 :

 # if(i[0].isalpha() or i == '_') and i.replace('_','').isalnum():
  if('a'<=data[0]<='z' or 'A'<=data[0]<='Z' or data[0] == '_'):
   if('a'<=data[1:]<='z' or 'A'<=data[1:]<='Z' or data[1:] == '_' or '0'<=data[1:]<='9'):
    print(i ,"is identifier")

  else:

    print(i,"is invalid identifier")
# Out:
# enter a stringhi i am joey 222 __fhdj
# hi is identifier
# i is identifier
# am is identifier
# joey is identifier
# 222 is identifier
# __fhdj is identifier
#  is identifier

# %% [markdown]
# 1. takes three number input
# 2. prints out the sum

# %%
a = int(input("enter the 1st number"))
b = int(input("enter the 2nd number"))
c = int(input("enter the 3rd number"))

sum = a+b+c

print(sum)
# Out:
# enter the 1st number1
# enter the 2nd number2
# enter the 3rd number3
# 6

# %% [markdown]
# 1. generate all possible valid identifier
#
# conditions:
#
# 1. of length n
# 2. n is input by user
# 3. takes n values from user and creates possible identifiers

# %% [markdown]
# if it is of length one then it should generate all alphabets or _ as output, cause all alphabets can be the possible output of length one and underscore can also be the output

# %% [markdown]
# 1. takes list of numbers as input from user
# 2. prints out maximum and minimum

# %%
numbers = []

count = int(input("enter the number of elements to be input:"))

data = range(count)

for i in data:
    num = int(input("number"))
    numbers.append(num)

#print(numbers)
minimum_value = min(numbers)
maximum_value = max(numbers)

print("minimum value is", minimum_value)
print("maximum value is", maximum_value)
# Out:
# enter the number of elements to be input:5
# number1
# number2
# number3
# number4
# number5
# minimum value is 1
# maximum value is 5

# %% [markdown]
# 1. takes two numbers as input from user
# 2. perform arithmetiv operation on them
# 3. display each operation

# %%
a = int(input("enter first number"))
b = int(input("enter second number"))

sum = a+b
diff= a-b
mul = a*b
div = a/b
mod = a%b

print("sum is", sum)
print("difference is", diff)
print("multiplication is", mul)
print("division is", div)
print("modulus is", mod)
# Out:
# enter first number5
# enter second number2
# sum is 7
# difference is 3
# multiplication is 10
# division is 2.5
# modulus is 1

# %% [markdown]
# 1. prompt to enter two number
# 2. compare number
# 3. display result

# %%
a = int(input("Enter the first number: "))
b = int(input("Enter the second number: "))


greater = a > b
less = a < b
equal = a == b
not_equal = a != b
is_greater_equal = a >= b
is_less_equal = a <= b



print("num1 > num2:", greater)
print("num1 < num2:", less)
print("num1 == num2:", equal)
print("num1 != num2:", not_equal)
print("num1 >= num2:", is_greater_equal)
print("num1 <= num2:", is_less_equal)
# Out:
# Enter the first number: 3
# Enter the second number: 5
# num1 > num2: False
# num1 < num2: True
# num1 == num2: False
# num1 != num2: True
# num1 >= num2: False
# num1 <= num2: True

# %% [markdown]
# 1. prompts user to enter their age
# 2. check if they are abled to vote
# 3. age greater than or equal to 18
# 4. less than or equal to 120
# 5. print msg

# %%
age = int(input("enter your age:"))

if age >= 18 and age <= 120:
  print("you are able to vote")
else:
  print("you are not able to vote")
# Out:
# enter your age:17
# you are not able to vote

# %% [markdown]
# 1. inputs from user
# 2. print multiplication table of that number

# %%
n = int(input("enter a number"))

p = int(input("enter the range"))

for i in range(1,p+1):

  print(n,"*",i,"=",n*i)
# Out:
# enter a number6
# enter the range20
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60
# 6 * 11 = 66
# 6 * 12 = 72
# 6 * 13 = 78
# 6 * 14 = 84
# 6 * 15 = 90
# 6 * 16 = 96
# 6 * 17 = 102
# 6 * 18 = 108
# 6 * 19 = 114
# 6 * 20 = 120

# %% [markdown]
# 1. to calculate the factorial of a number recursively

# %%
# Out:
# Enter a number to calculate its factorial: 5
# The factorial of 5 is: 120

# %% [markdown]
# ![Screenshot 2024-10-13 at 4.50.43 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-13 at 4.51.15 PM.png](data:image/png;base64,...)

# %%
a = int(input("enter the number"))

if a == 0:

  print("a is zero")

elif a%2 == 0:

  print(a,"is even")

else:
  print(a,"is odd")
# Out:
# enter the number5
# 5 is odd

# %% [markdown]
# 2. leap year

# %%
year = int(input("enter the year"))

if year%4 == 0 or year%400 == 0 or year%100:
  print(year,"is a leap year")
else:
  print(year,"is not a leap year")
# Out:
# enter the year2024
# 2024 is a leap year

# %% [markdown]
# 3.find greatest among three numbers

# %%
a = int(input("enter 1st number"))
b = int(input("enter 2nd number"))
c = int(input("enter 3rd number"))

if a>b and a>c:
  print(a,"is greatest")
elif b>a and b>c:
  print(b,"is greatest")
else:
  print(c,"is greatest")
# Out:
# enter 1st number1
# enter 2nd number2
# enter 3rd number3
# 3 is greatest

# %% [markdown]
# 1. accept age , sex,number of days
# 2. display wages

# %%
age = int(input("enter the age"))
sex = input("enter the sex")
days = int(input("enter the number of days"))

if age >=18 and age<=30 and sex == "M":

  print("wages:",days*700)

elif age >=18 and age<=30 and sex == "F":

  print("wages:",days*750)

elif age >=30 and age<=40 and sex == "M":

  print("wages:",days*800)

elif age >=30 and age<=40 and sex == "F":

  print("wages:",days*850)

else:
  print("enter valid details")
# Out:
# enter the age18
# enter the sexM
# enter the number of days18
# wages: 12600

# %% [markdown]
# 1. 10% discount
# 2. cost of purchased is  >1000
# 3. user input quantity
# 4. one unit = 100

# %%
quantity =int(input("enter the quantity"))

if quantity*100 > 1000:
  #print("actual cost:",(quantity*100))
  #print("discount price:",(.1*quantity*100))
  print("final cost:",((quantity*100)-(.1*quantity*100)))
else:
  print("cost:",quantity*100)
# Out:
# enter the quantity15
# actual cost: 1500
# discount price: 150.0
# final cost: 1350.0

# %% [markdown]
# 1. triangle - check equilateral,isosceles,scalene
#
# conditions
#
# 1. equilateral : 3 sides equal
# 2. scalene : 3 sides unequal
# 3. isosceles : 2 sides equal

# %%
side1 = float(input("enter the 1st length"))
side2 = float(input("enter the 2nd length"))
side3 = float(input("enter the 3rd length"))

if side1 == side2 == side3:
  print("equilateral triangle")
elif side1 == side2 or side1 == side3 or side2 == side3:
  print("isosceles triangle")
else:
  print("scalene triangle")

# %% [markdown]
# 1. accept two numbers
# 2. accept mathematical operator
# 3. print output

# %%
a = int(input("enter 1st number"))
b = int(input("enter 2nd number"))
op = input("enter the operator")

if op == "+":
  print("your answer is:",a+b)
elif op == "-":
  print("your answer is:",a-b)
elif op == "*":
  print("your answer is:",a*b)
elif op == "/":
  print("your answer is:",a/b)
elif op == "%":
  print("your answer is:",a%b)
elif op == "//":
  print("your answer is:",a//b)
elif op == "**":
  print("your answer is:",a**b)
else:
  print("enter valid operator")
# Out:
# enter 1st number5
# enter 2nd number4
# enter the operator+
# your answer is: 9

# %% [markdown]
# 1. grading system
# 2. enter mark and print corresponding grade

# %%
mark = int(input("enter the marks"))

if mark>80:

  print("A")
elif mark>60 and mark<=80:
  print("B")
elif mark>50 and mark<=60:
  print("C")
elif mark>45 and mark<=50:
  print("D")
elif mark>=25 and mark<=45:
  print("E")
else:
  print("F")
# Out:
# enter the marks30
# E

# %% [markdown]
# 1. accept city from user
# 2. display monument of city

# %%
city = input("enter the city")

if city == "delhi":
  print("monument of delhi : red fort")
elif city == "agra":
  print("monument of delhi : taj mahal")
elif city == "jaipur":
  print("monument of delhi : jal mahal")
# Out:
# enter the citydelhi
# monument of delhi : red fort

# %% [markdown]
# 1. take values of length and breadth
# 2. check if its square or not

# %%
length = int(input("enter the length"))
breadth = int(input("enter the breadth"))

if length == breadth:
  print("its a square")
else:
  print("its a rectangle")
# Out:
# enter the length12
# enter the breadth13
# its a rectangle
