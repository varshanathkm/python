# %% [markdown]
# #data inspect methods

# %% [markdown]
# ##data analyse methods

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';')

# %%
df.head(3)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0

# %%
df.tail(2)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age Gender EverBenched  \
# 4651  Bachelors         2012  Bangalore            3   30   Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33   Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4651                          2           0
# 4652                          4           0

# %%
df.info() #each columns datatype is get
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
#shape method
df.shape
#returns the shape of data or rows or columns
# Out:
# (4653, 9)

# %%
df.columns
#returns the columns name
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
#dimension checking
df.ndim
#returns the dimension of data
# Out:
# 2

# %%
df.values #it returns the datas in array format , it is mainly used to store the data values in array format
# Out:
# array([['Bachelors', 2017, 'Bangalore', ..., 'No', 0, 0],
#        ['Bachelors', 2013, 'Pune', ..., 'No', 3, 1],
#        ['Bachelors', 2014, 'New Delhi', ..., 'No', 2, 0],
#        ...,
#        ['Masters', 2018, 'New Delhi', ..., 'No', 5, 1],
#        ['Bachelors', 2012, 'Bangalore', ..., 'Yes', 2, 0],
#        ['Bachelors', 2015, 'Bangalore', ..., 'Yes', 4, 0]], dtype=object)

# %%
df.size #used to get size , its an attribute
# Out:
# 41877

# %%
df['Education'].value_counts() #used to get the amount of times certain value is get
# Out:
# Education
# Bachelors    3601
# Masters       873
# PHD           179
# Name: count, dtype: int64

# %%
#unique method
#used to get unique values in the column
df['Education'].unique()
# Out:
# array(['Bachelors', 'Masters', 'PHD'], dtype=object)

# %%
#if header=0 then the column names will be shows cause it starts from the top row otherwise if its 1 then it starts from the first row so no column names if its none the column name would be there but not as specific column name it would be as row of data
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',header=1)

# %%
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',header=None)

# %%
#to specify column names from user side we use names argument
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',header=None,names=['A','B','C','D','E','F','G','H','I'])

# %%
df.head()
# Out:
#            A            B          C            D    E       F            G  \
# 0  Education  JoiningYear       City  PaymentTier  Age  Gender  EverBenched
# 1  Bachelors         2017  Bangalore            3   34    Male           No
# 2  Bachelors         2013       Pune            1   28  Female           No
# 3  Bachelors         2014  New Delhi            3   38  Female           No
# 4    Masters         2016  Bangalore            3   27    Male           No
#
#                            H           I
# 0  ExperienceInCurrentDomain  LeaveOrNot
# 1                          0           0
# 2                          3           1
# 3                          2           0
# 4                          5           1

# %%
#when we read a data if we want any of the starting rows to be skipped then we use skip rows parameter and assign the value of no. of row to be removed then we get the dataframe with no. of row skipped
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',header=None,names=['A','B','C','D','E','F','G','H','I'],skiprows=1)

# %%
df.head()
# Out:
#            A     B          C  D   E       F    G  H  I
# 0  Bachelors  2017  Bangalore  3  34    Male   No  0  0
# 1  Bachelors  2013       Pune  1  28  Female   No  3  1
# 2  Bachelors  2014  New Delhi  3  38  Female   No  2  0
# 3    Masters  2016  Bangalore  3  27    Male   No  5  1
# 4    Masters  2017       Pune  3  24    Male  Yes  2  1

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/data1.csv',sep=';',names=['id','name','sub','mark'],skiprows=1)

# %%
df
# Out:
#    id    name   sub  mark
# 0   1    Alex  sub1    98
# 1   2     Amy  sub2    90
# 2   3   Allen  sub4    87
# 3   4   Alice  sub6    69
# 4   5  Ayoung  sub5    78
# 5   6  sarang  sub6    87

# %%
#need to change datatype of mark to float or any datatype of dataset we can use dtype argument
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/data1.csv',sep=';',names=['id','name','sub','mark'],skiprows=1,dtype={'mark':float})

# %%
df
# Out:
#    id    name   sub  mark
# 0   1    Alex  sub1  98.0
# 1   2     Amy  sub2  90.0
# 2   3   Allen  sub4  87.0
# 3   4   Alice  sub6  69.0
# 4   5  Ayoung  sub5  78.0
# 5   6  sarang  sub6  87.0

# %%
#nrows - if we only want to read particular amount of rows
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/data1.csv',sep=';',names=['id','name','sub','mark'],skiprows=1,dtype={'mark':float},nrows=2)

# %%
df
# Out:
#    id  name   sub  mark
# 0   1  Alex  sub1  98.0
# 1   2   Amy  sub2  90.0

# %%
#index_col - if we want to set any of the columns in the data as index column
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/data1.csv',sep=';',names=['id','name','sub','mark'],skiprows=1,dtype={'mark':float},nrows=2,index_col='name')

# %%
df
# Out:
#       id   sub  mark
# name
# Alex   1  sub1  98.0
# Amy    2  sub2  90.0

# %%
#parse_dates- used to convert a datatype of data in dataset to datetime format
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',parse_dates=['JoiningYear'])

# %%
df
# Out:
#       Education JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors  2017-01-01  Bangalore            3   34    Male          No
# 1     Bachelors  2013-01-01       Pune            1   28  Female          No
# 2     Bachelors  2014-01-01  New Delhi            3   38  Female          No
# 3       Masters  2016-01-01  Bangalore            3   27    Male          No
# 4       Masters  2017-01-01       Pune            3   24    Male         Yes
# ...         ...         ...        ...          ...  ...     ...         ...
# 4648  Bachelors  2013-01-01  Bangalore            3   26  Female          No
# 4649    Masters  2013-01-01       Pune            2   37    Male          No
# 4650    Masters  2018-01-01  New Delhi            3   27    Male          No
# 4651  Bachelors  2012-01-01  Bangalore            3   30    Male         Yes
# 4652  Bachelors  2015-01-01  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   datetime64[ns]
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 327.3+ KB

# %%
#used to skip the rows from below to above
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',skipfooter=4500)
# Out:
# <ipython-input-41-293b39250ddc>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',skipfooter=4500)

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
#usecols- by using this paramater we can only the necessary columns and there is no need to drop the unwanted colums
df=pd.read_csv('/content/drive/MyDrive/data science/python/pandas/PANDAS (lib)/datasets used/employe.csv',sep=';',usecols=['Age','City'])

# %%
df.head()
# Out:
#         City  Age
# 0  Bangalore   34
# 1       Pune   28
# 2  New Delhi   38
# 3  Bangalore   27
# 4       Pune   24

# %%
#used to save the updated data as a new csv file we can used method to_csv
df.to_csv('new.csv')
