# %% [markdown]
# #Add

# %%
data = 45

data1= 66

data2 = data+ data1

print(data2)
# Out:
# 111

# %% [markdown]
# #sub

# %%
data = 45

data1= 66

data2 = data - data1

print(data2)
# Out:
# -21

# %% [markdown]
# # mul

# %%
data = 45

data1= 66

data2 = data * data1

print(data2)
# Out:
# 2970

# %% [markdown]
# # div

# %%
data = 66

data1= 33

data2 = data / data1

print(data2)
# Out:
# 2.0

# %% [markdown]
# # modulus

# %%
data = 334

data1= 66

data2 = data / data1

print(data2)
# Out:
# 5.0606060606060606

# %% [markdown]
# #exponential

# %%
data = 3

data1= 9

data2 = data ** data1

print(data2)
# Out:
# 19683

# %% [markdown]
# # floor division

# %%
data = 334

data1= 66

data2 = data // data1

print(data2)
# Out:
# 5

# %% [markdown]
# ## += operator

# %%
data = 5

data += data

print(data)
# Out:
# 10

# %% [markdown]
# # -=

# %%
x= 30

x-=40 #x=x-40
print(x)

# %% [markdown]
# # *=

# %%
x= 30

x*=40
print(x)

# %% [markdown]
# # /=

# %%
x= 30

x/=40
print(x)

# %% [markdown]
# # **=

# %%
x= 30

x**=40
print(x)
# Out:
# 121576654590569288010000000000000000000000000000000000000000

# %% [markdown]
# #comparison operators

# %% [markdown]
# ##equal operator ==

# %%
x=60
y=90

z=x==y
print(z)

z=print(type(x))==print(type(y))

print(z)
# Out:
# False
# <class 'int'>
# <class 'int'>
# True

# %% [markdown]
# ##not equal operator !=

# %%
x=60
y=90

z=x==y
print(z)

z=print(type(x))!=print(type(y))

print(z)
# Out:
# False
# <class 'int'>
# <class 'int'>
# False

# %% [markdown]
# ##greater than operator >

# %%
x=60
y=90

z=x>y
print(z)
# Out:
# False

# %% [markdown]
# #less than <

# %%
x=60
y=90

z=x<y
print(z)
# Out:
# True

# %% [markdown]
# #greater than or eq >=

# %%
x=60
y=90

z=x>=y
print(z)
# Out:
# False

# %% [markdown]
# #less than or eq <=

# %%
x=60
y=90

z=x<=y
print(z)
# Out:
# True

# %% [markdown]
# #logical operator

# %% [markdown]
# #AND
#
# # true and true   #true
# # true and false   #false
# # false and true   #false
# # false and false  #false
#
# #OR
#
# #true and true  #true
# #true and false  #true
# #false and true  #true
# #false and false #false
#
# #NOT
#
# #not true   #false
# #not false  #true

# %% [markdown]
# #input function

# %%
exp = int(input("enter the experience = "))
qlf = input("enter the qlf =")

print(exp)
print(qlf)

print(type(exp))
print(type(qlf))
# Out:
# enter the experience = 3
# enter the qlf =MBA
# 3
# MBA
# <class 'int'>
# <class 'str'>

# %%
exp = int(input("enter the experience = "))
qlf = input("enter the qlf =")

x = exp > 2 and qlf == 'MBA'

print(x)
# Out:
# enter the experience = 3
# enter the qlf =MBA
# True

# %%
exp = int(input("enter the experience = "))
qlf = input("enter the qlf =")

x = exp > 5 or qlf == 'MCA'

print(x)
# Out:
# enter the experience = 6
# enter the qlf =MCA
# True

# %% [markdown]
# ##IDENTITY OPERATORS

# %% [markdown]
# #is

# %%
x= 40
y=90

z= x is y

print(z)
# Out:
# False

# %% [markdown]
# #is not

# %%
x= 40
y=90

z= x is not y

print(z)
# Out:
# True

# %% [markdown]
# #membership operator

# %% [markdown]
# ##in and not in operator

# %%
data = "hello raju how are you"

print('raju' in data)
# Out:
# True

# %%
data = "hello raju how are you"

print('raju' not in data)
# Out:
# False
